# %% [markdown]
# # Creating a Filter, Edge Detection

# %% [markdown]
# ### Import resources and display image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %matplotlib inline

# Read in the image
image_lane = mpimg.imread('images/curved_lane.jpg')

plt.imshow(image_lane)

# %% [markdown]
# ### Convert the image to grayscale

# %%
# Convert to grayscale for filtering
image_copy = np.copy(image_lane)
image_rgb = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

gray_lane = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_lane, cmap='gray')

# %% [markdown]
# ### TODO: Create a custom kernel
#
# Below, you've been given one common type of edge detection filter: a Sobel operator.
#
# The Sobel filter is very commonly used in edge detection and in finding patterns in intensity in an image. Applying a Sobel filter to an image is a way of **taking (an approximation) of the derivative of the image** in the x or y direction, separately. The operators look as follows.
#
# <img src="images/sobel_ops.png" width=200 height=200>
#
# **It's up to you to create a Sobel x operator and apply it to the given image.**
#
# For a challenge, see if you can put the image through a series of filters: first one that blurs the image (takes an average of pixels), and then one that detects the edges.

# %%
# Create a custom kernel
# 3x3 array for edge detection 
# Create and apply a Sobel x operator
sobel_x_3 = np.array([[ -1, 0, 1], 
                   [ -2, 0, 2], 
                   [ -1, 0, 1]])


# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
image_sobel_x_3 = cv2.filter2D(gray_lane, -1, sobel_x_3)

plt.imshow(image_sobel_x_3, cmap='gray')

# %% [markdown]
# ### Test out other filters!
#
# You're encouraged to create other kinds of filters and apply them to see what happens! As an **optional exercise**, try the following:
# * Create a filter with decimal value weights.
# * Create a 5x5 filter
# * Apply your filters to the other images in the `images` directory.

# %%
# Create a custom kernel
## TODO: Create and apply a Sobel y operator
sobel_y_3 = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])


# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
image_sobel_y_3 = cv2.filter2D(gray_lane, -1, sobel_y_3)

plt.imshow(image_sobel_y_3, cmap='gray')

# %%
# Create a custom kernel
# 3x3 array for edge detection with decimal values - small: 0.5
# Create and apply a Sobel x operator
sobel_dec_x_05 = np.array([[ -0.5, 0.0, 0.5], 
                   [ -1.0, 0.0, 1.0], 
                   [ -0.5, 0.0, 0.5]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
image_sobel__dec_x_05 = cv2.filter2D(gray_lane, -1, sobel_dec_x_05)

plt.imshow(image_sobel__dec_x_05, cmap='gray')

# %%
sobel_dec_y_05 = np.array([[ -0.5, -1.0, -0.5], 
                   [ 0.0, 0.0, 0.0], 
                   [ 0.5, 1.0, 0.5]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
image_sobel__dec_y_05 = cv2.filter2D(gray_lane, -1, sobel_dec_y_05)

plt.imshow(image_sobel__dec_y_05, cmap='gray')

# %%
# Create a custom kernel
# 3x3 array for edge detection with decimal values - large: 2.5
# Create and apply a Sobel x operator
sobel_dec_x_25 = np.array([[ -2.5, 0.0, 2.5], 
                   [ -5.0, 0.0, 5.0], 
                   [ -2.5, 0.0, 2.5]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
image_sobel__dec_x_25 = cv2.filter2D(gray_lane, -1, sobel_dec_x_25)

plt.imshow(image_sobel__dec_x_25, cmap='gray')

# %%
sobel_dec_y_25 = np.array([[ -2.5, -5.0, -2.5], 
                   [ 0.0, 0.0, 0.0], 
                   [ 2.5, 5.0, 2.5]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
image_sobel__dec_y_25 = cv2.filter2D(gray_lane, -1, sobel_dec_y_25)

plt.imshow(image_sobel__dec_y_25, cmap='gray')

# %%
# load new image
# Read in the image
image_trees = mpimg.imread('images/bridge_trees_example.jpg')

plt.imshow(image_trees)

# %%
# Convert to grayscale for filtering
image_copy = np.copy(image_trees)
image_rgb = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

gray_trees = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_trees, cmap='gray')

# %%
## TODO: Create and apply a Sobel x operator 5x5 kernel
sobel_x_5 = np.array([[ -1, -1, 0, 1, 1], 
                   [ -2, -2, 0, 2, 2], 
                   [ -2, -2, 0, 2, 2],
                   [ -2, -2, 0, 2, 2],
                   [ -1, -1, 0, 1, 1]])


# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
image_sobel_x_5 = cv2.filter2D(gray_trees, -1, sobel_x_5)

plt.imshow(image_sobel_x_5, cmap='gray')

# %%
# Create a custom kernel 5x5

# 5x5 array for edge detection
#Create and apply a Sobel y operator
sobel_y_5 = np.array([[ -1, -2, -2, -2, -1], 
                   [ -1, -2, -2, -2, -1], 
                   [ 0, 0, 0, 0, 0],
                   [ 1, 2, 2, 2, 1],
                   [ 1, 2, 2, 2, 1]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
image_sobel_y_5 = cv2.filter2D(gray_trees, -1, sobel_y_5)

plt.imshow(image_sobel_y_5, cmap='gray')

# %%
# Load new image
# Read in the image
image_lines = mpimg.imread('images/white_lines.jpg')

plt.imshow(image_lines)

# %%
# Convert to grayscale for filtering
image_copy = np.copy(image_lines)
image_rgb = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

gray_lines = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_lines, cmap='gray')

# %%
# blurr image with OpenCV
# average filter
avg_filter = cv2.blur(gray_lines,(50,50)) # kernel 50x50

plt.imshow(avg_filter, cmap='gray')

# %%
# blurr image with OpenCV
# Gaussian filter
gaussian_blur_filter = cv2.GaussianBlur(gray_lines, (55,55),0)

plt.imshow(gaussian_blur_filter, cmap='gray')

# %%
# blurr image with OpenCV
# Median filter
median_blur_filter = cv2.medianBlur(gray_lines,55)

plt.imshow(median_blur_filter, cmap='gray')

# %%
# blurr image with OpenCV
# Bilateral filter
bilateral_filter = cv2.bilateralFilter(gray_lines,35,125,125) 

plt.imshow(bilateral_filter, cmap='gray')
